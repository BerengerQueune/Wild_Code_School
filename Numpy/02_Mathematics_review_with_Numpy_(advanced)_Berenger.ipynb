# %% [markdown]
# ## Mission 4
#
# Create a function using Numpy that solves [second degree equations of this kind](https://www.youtube.com/watch?v=hwq_zpsGixc): $ax^2+bx+c$

# %%
import numpy as np

p = [1, 5, 6]

def secondDegreeEquation (number):

  return np.roots(number)

secondDegreeEquation(p)
# Out:
# array([-3., -2.])

# %% [markdown]
# ## Mission 5
#
# Re-code the Gaussian curve using NumPy functions instead of Python functions.

# %%
# Code with Python

import numpy as np
import matplotlib.pyplot as plt
from math import sqrt, pi, exp

domain = range(-100,100)
mu = 0
sigma = 20

f = lambda x : 1/(sqrt(2*pi*pow(sigma,2))) * exp(-pow((x-mu),2)/(2*pow(sigma,2)))

y = [f(x) for x in domain]
plot = plt.plot(domain, y)

# %%
# New Code

import numpy as np
import matplotlib.pyplot as plt

domain = np.linspace(-100,100)
mu = 0
sigma = 20

f = lambda x : 1/(np.sqrt(2*np.pi*np.power(sigma,2))) * np.exp(-np.power((x-mu),2)/(2*np.power(sigma,2)))

y = [f(x) for x in domain]
plot = plt.plot(domain, y)

# %%
# Test

import numpy as np
import matplotlib.pyplot as plt

domain = np.linspace(-100,100)
mu = 0
sigma = 20

f = 1/(np.sqrt(2*np.pi*np.power(sigma,2))) * np.exp(-np.power((domain-mu),2)/(2*np.power(sigma,2)))

plot = plt.plot(domain, y)
